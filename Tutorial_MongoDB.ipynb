# %% [markdown]
# # Tutorial — MongoDB with clever-cloud.com

# %% [markdown]
# ## 1. Connect to MongoDB with Python

# %% [markdown]
# Imports needed to connect with MongoDB. No expected output.

# %%
import pymongo
from pymongo import MongoClient

# %% [markdown]
# A `uri` will allow you to create a connection with the MongoDB instance you have created in Clever-Cloud. This connection is called a "client". This `uri` can be found on your "Database credentials" dashboard under "Connection URI". Copy/paste it below.

# %%
uri = 'mongodb://ue8eadbecr19tspjxpml:MMexDIJFCb2bW80bZzog@n1-c2-mongodb-clevercloud-customers.services.clever-cloud.com:27017,n2-c2-mongodb-clevercloud-customers.services.clever-cloud.com:27017/bt3af6edkiqnoj8?replicaSet=rs0'  # insert here URI from your MongoDB instance
client = MongoClient( uri )
client.stats
# Out:
# Database(MongoClient(host=['n1-c2-mongodb-clevercloud-customers.services.clever-cloud.com:27017', 'n2-c2-mongodb-clevercloud-customers.services.clever-cloud.com:27017'], document_class=dict, tz_aware=False, connect=True, replicaset='rs0'), 'stats')

# %% [markdown]
# **Expected output:**
#
# ```
# Database(MongoClient(host=['xxxxxxxxxxxxxx'], document_class=dict, tz_aware=False, connect=True), 'stats')
# ```

# %% [markdown]
# NB: String "xxxxxxxxxxxxxx" will be replaced with your credentials.

# %% [markdown]
# You then have to access a specific database prepared by Clever-Cloud for your add-on. The name of this database is to be found on your "Database credentials" dashboard under "Database Name".

# %%
db = client['bt3af6edkiqnoj8']  # insert here name of database from your MongoDB instance
client.list_database_names()
# Out:
# []

# %% [markdown]
# **Expected output:**
#
# ```
# []
# ```

# %% [markdown]
# NB: The data base will be created once a document is added in it, so the list above should be empty at the very beginning.

# %% [markdown]
# ## 2. MongoDB operations

# %% [markdown]
# Let us now test a few basic MongoDB operations to be sure everything works well. We will learn more MongoDB operations later during the course. Instanciate a collection named "mycollection". No expected outpout.

# %%
collection = db['mycollection']

# %% [markdown]
# Insert three documents in the collection. No expected output.

# %%
documents = [
    {"field_1": "one", "field_2": 1},
    {"field_1": "two", "field_2": 2},
    {"field_1": "three", "field_2": 3}
]
result = collection.insert_many(documents)

# %% [markdown]
# And get documents back from your collection:

# %%
query = {}
with collection.find(query, no_cursor_timeout=True) as cursor:
    for document in cursor:
        print(document)
# Out:
# {'_id': ObjectId('641824eddec5607e9d3993f2'), 'field_1': 'one', 'field_2': 1}
# {'_id': ObjectId('641824eddec5607e9d3993f3'), 'field_1': 'two', 'field_2': 2}
# {'_id': ObjectId('641824eddec5607e9d3993f4'), 'field_1': 'three', 'field_2': 3}
# {'_id': ObjectId('641824f5dec5607e9d3993f5'), 'field_1': 'one', 'field_2': 1}
# {'_id': ObjectId('641824f5dec5607e9d3993f6'), 'field_1': 'two', 'field_2': 2}
# {'_id': ObjectId('641824f5dec5607e9d3993f7'), 'field_1': 'three', 'field_2': 3}
# {'_id': ObjectId('64182502dec5607e9d3993f8'), 'field_1': 'one', 'field_2': 1}
# {'_id': ObjectId('64182502dec5607e9d3993f9'), 'field_1': 'two', 'field_2': 2}
# {'_id': ObjectId('64182502dec5607e9d3993fa'), 'field_1': 'three', 'field_2': 3}
# ...

# %% [markdown]
# **Expected output:**
#
# ```
# {'_id': ObjectId('60313848a51679dc9426cdb7'), 'field_1': 'one', 'field_2': 1}
# {'_id': ObjectId('60313848a51679dc9426cdb8'), 'field_1': 'two', 'field_2': 2}
# {'_id': ObjectId('60313848a51679dc9426cdb9'), 'field_1': 'three', 'field_2': 3}
# ```

# %% [markdown]
# NB: Values under "ObjectId" may vary.

# %% [markdown]
# **Let's create accommodations database:**

# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /var/folders/9z/ss1v3r3n1q79hcgm5mgp_6f80000gn/T/ipykernel_58123/3775722731.py in <module>
# ----> 1 from google.colab import drive
#       2 drive.mount('/content/gdrive', force_remount=True)
#
# ModuleNotFoundError: No module named 'google'

# %%
import os
print(os.listdir('/content/gdrive/MyDrive/STATS502/practical_sessions/4.DocumentOrientedDatabase'))
# Out:
# ['Tutorial_MongoDB.ipynb', 'Document-OrientedDatabaseCorrection.ipynb', 'Document-OrientedDatabase.ipynb', 'TutorialMongoDB.pages', 'TutorialMongoDB.pdf', 'accommodations.json', 'MongoDB']

# %%
import json

client.list_database_names()
accommodations = db['accommodations']

# %%
for line in open("/content/gdrive/MyDrive/STATS502/practical_sessions/4.DocumentOrientedDatabase/accommodations.json", 'r'):
    accommodation = json.loads(line)
    if '_id' in accommodation:
        del accommodation['_id']
    db['accommodations'].insert_one(accommodation)

# %%
result = db['accommodations'].find_one()
print(result)
# Out:
# {'_id': ObjectId('6403752343b458745f5cc4bc'), 'bathrooms': 1, 'reviews': [], 'listing_url': 'https://www.airbnb.com/rooms/14690527', 'price': 150, 'street': 'Conway Street, Boston, MA 02131, United States', 'id': 14690527, 'city': 'Boston', 'name': '1 Bedroom Home Suite Home', 'bed_type': 'Real Bed', 'summary': "My place is good for couples, solo adventurers, business travelers, and families (with kids).  A clean space you can relax in and entertain yourself with the trinkets we've collected and placed thoughtfully throughout our home. We are conveniently located on a street that ends into the Harvard Arboretum on one end and has the Roslindale Village Commuter Rail at the other with a short cut path into Roslindale Village for shops and dinning.", 'beds': 2, 'minimum_nights': 1, 'cleaning_fee': 0, 'host_name': 'Crystal', 'maximum_nights': 1125}

# %% [markdown]
# -----

# %% [markdown]
# #### If you got all the expected outputs, you are ready for the practical sessions!
